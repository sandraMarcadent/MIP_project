# %%
from helpers import show_normed_gray_image
from data_loader import Data_loader

# %%
loader_object = Data_loader()

# %%
loader_object.build_data()
# Out:
# specified target data loader:  (0, 512, 512, 1)
# 0 b'Fluorospot_Compact_FD'
# len : 3264
# 1 b'CXDI'
# len : 132
# 2 b'DX-G'
# len : 308
# 3 b'PCR_Eleva'
# len : 10
# 4 b'Essenta_DR_Compact'
# len : 71
# 5 b'DigitalDiagnost'
# len : 7095
# 0 b'Fluorospot_Compact_FD'
# len : 3264
# 1 b'CXDI'
# len : 132
# 2 b'DX-G'
# len : 308
# 3 b'PCR_Eleva'
# len : 10
# 4 b'Essenta_DR_Compact'
# len : 71
# 5 b'DigitalDiagnost'
# len : 7095
# WARNING: you are not going to preprocess
# check images properties
# data size is :  (10880, 512, 512, 1)

# %%
a_x = loader_object.processed_a
b_x = loader_object.processed_b

# %%
imgs = loader_object.processed_b

show_normed_gray_image(imgs,idx=1)

# %%
len(loader_object.processed_b)
# Out:
# 3785
