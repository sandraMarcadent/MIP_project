# %% [markdown]
# ### copying cxr8

# %%
import os
from distutils.dir_util import copy_tree

# %%
fromDirectory = '/home/shared/datasets/cxr8/images'
toDirectory = '/home/sandra/project_GANs/project_GANs_data_mining/cxr8'

#copy_tree(fromDirectory, toDirectory)
# Out:
# ['/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_002.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_011.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_008.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_010.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_003.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_001.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_006.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_009.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_012.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_004.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_005.tar.gz',
#  '/home/sandra/project_GANs/project_GANs_data_mining/cwr8/images_007.tar.gz']

# %% [markdown]
# ### copying cycle GAN template on cxr8

# %%
os.chdir('/home/sandra/project_GANs/project_GANs_data_mining/cycle_GAN_on_cxr8')

# %%
fromDirectory = '/home/sandra/project_GANs/project_GANs_data_mining/cycle_GAN_on_cxr8'
toDirectory = '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8'

# %%
copy_tree(fromDirectory, toDirectory)
# Out:
# ['/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/layers.py',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/model.py',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/losses.py',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/get_parameters.py',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/output/cyclegan/exp_01/20180307-145804/cyclegan-2.data-00000-of-00001',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/output/cyclegan/exp_01/20180307-145804/imgs/fakeB_1_1.jpg',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/output/cyclegan/exp_01/20180307-145804/imgs/fakeA_2_0.jpg',
#  '/home/sandra/project_GANs/project_GANs_data_mining/DTN_GAN_on_cxr8/output/cyclegan/exp_01/20180307-145804/imgs/fakeA_1_1.jpg',
# ...

# %%
fromDirectory = '/home/sandra/project_GANs/data_mining_cxr8_unknown/cycle_GAN_on_cxr8'
toDirectory = '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5'

copy_tree(fromDirectory, toDirectory)
# Out:
# ['/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/layers.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/model.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/losses.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/get_parameters.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180307-145804/cyclegan-2.data-00000-of-00001',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180307-145804/imgs/fakeB_1_1.jpg',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180307-145804/imgs/fakeA_2_0.jpg',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180307-145804/imgs/fakeA_1_1.jpg',
# ...

# %%
fromDirectory = '/home/sandra/project_GANs/data_mining_cxr8_hdf5/cycle_GAN_on_cxr8_hdf5'
toDirectory = '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5'

copy_tree(fromDirectory, toDirectory)
# Out:
# ['/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/layers.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/model.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/parameters.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/losses.py',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/test_class_data_loader.ipynb',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180309-135023/checkpoint',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180309-135023/cyclegan-0.index',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180309-135023/cyclegan-0.data-00000-of-00001',
#  '/home/sandra/project_GANs/data_mining_cxr8_hdf5/DTN_GAN_on_cxr8_hdf5/output/cyclegan/exp_01/20180309-135023/imgs_train/inputA_0_1.jpg',
# ...

# %%
fromDirectory = '/home/sandra/project_GANs/general/cycle_GAN_version_09_2017'
toDirectory = '/home/sandra/project_GANs/general/home_made_DTN_on_zebras'

copy_tree(fromDirectory, toDirectory)
# Out:
# ['/home/sandra/project_GANs/general/home_made_DTN_on_zebras/cyclegan_datasets.py',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/imgs/skip_result.jpg',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/imgs/horse2zebra.png',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/layers.py',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/LICENSE',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/main.py',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/model.py',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/README.md',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/.git/config',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/.git/description',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/.git/hooks/pre-push.sample',
#  '/home/sandra/project_GANs/general/home_made_DTN_on_zebras/.git/hooks/update.sample',
# ...

# %%
fromDirectory = '/mnt/dataC/project_GANs/data_mining_cxr8_hdf5'
toDirectory = '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic'

copy_tree(fromDirectory, toDirectory)
# Out:
# ['/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/layers.cpython-36.pyc',
#  '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/model.cpython-36.pyc',
#  '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/losses.cpython-36.pyc',
#  '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/data_loader.cpython-36.pyc',
#  '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/get_parameters.cpython-36.pyc',
#  '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/helpers.cpython-36.pyc',
#  '/mnt/dataC/project_GANs/HUGxGAN_deep_learning/cycle_GAN_basic/cycle_GAN_on_cxr8_hdf5/__pycache__/parameters.cpython-36.pyc',
# ...
